# %% [markdown]
# ## **🕹 Data Description 🕹**
#
# **StartUp Investments (Crunchbase) ([link datasets](https://www.kaggle.com/datasets/arindam235/startup-investments-crunchbase))**
#
# **Startup Success Prediction ([link datasets](https://www.kaggle.com/datasets/manishkc06/startup-success-prediction))**
#
# Data didapatkan melalui data pada `Crunchbase` is a company providing business information about private and public companies. Their content includes investment and funding information, founding members and individuals in leadership positions, mergers and acquisitions, news, and industry trends.
#
# Ppredict whether a startup would fail using the CrunchBase dataset. Usually, someone would need an Enterprise account to access this data, but I was able to find a copy from not too long ago. CrunchBase is an excellent resource for venture capital firms to learn about the companies that they might invest in. A lot of them pay extra for the Enterprise access to get additional features like advanced searches.
#
# **Dataset Description:**
#
# The training dataset contains `2240 samples`. Contains `28 features` and `1 target boolean` variable `"Response"` :
#
# **Startup Info**
#
# - `permalink` (string) -  link in crunchbase api, unique identifier within "Organization" namespace
# - `name` (string) -  startup name, User-friendly name (as presented on CrunchBase)
# - `homepage_url` (url)- website, Fully-qualified URL
# - `category_list` -  list of market categories
# - `market` - market direction
# - `funding_total_usd` - total funds in $
# - `status` - startup's working status
#     - `acquired` : startup acquisition is a deal in which a young company is sold to a new owner. Usually (though not always), a bigger, more successful company purchases a smaller startup. Unlike mergers, acquisitions do not result in the formation of a new company. Instead, the purchased company gets fully absorbed by the acquiring company. Sometimes this means the acquired company gets liquidated. Acquiring a business is similar to buying an existing business or franchise.
#     - `operating` : Type startup is still in the process, including market conditions, funding, and business strategies.
#     - `closed` : startups fail as it’s difficult for emerging companies to find a place in the market, compete with established competitors, and make a profit
#
# - `country_code`
#     - `state_code`
#     - `region`
#     - `city`
#
# - `funding_rounds` - number of the rounds, Funding Rounds are events wherein an Organization receives money from a Person or Organization.
# - `founded_at` - first official funding stage
#     - `founded_month`
#     - `founded_quarter`
#     - `founded_year`
# - `first_funding_at`
# - `last_funding_at`
#
# **Funding Type**
#
#
# `Seed funding` is the early stage of venture capital financing where a startup company obtains capital in order to finance the business' initial operations. The term "seed" refers to the fact that this is the earliest stage of funding and that the company is just getting started. Seed funding can come from a variety of sources, including `angel investors`, `venture capitalists`, and `crowdfunding`.
#
# - `Angel investors` are individuals who invest their own money in startups. They are often wealthy individuals who have a personal interest in the company or the industry.
#
# - `Venture capitalists` are professional investors who invest other people's money in startups. They are typically more risk-averse than angel investors and often require a higher return on investment.
#
# - `Crowdfunding` is a way for startups to raise money from a large number of people. Usually, this is done through an online platform, such as Kickstarter or Indiegogo. Startups will set a fundraising goal and offer rewards to people who contribute.
#
# `Equity Financing (Bagi Hasil)` adalah akad kerja sama antar bank/company sebagai pemilik modal dan nasabah sebagai pengelola modal untuk memperoleh keuntungan dan membagi keuntungan yang diperoleh berdasarkan nisbah yang disepakati.
#
# `Seed funding` is an important step for startups as it allows them to get the capital they need to get their business off the ground. However, it is also a risky investment as there is no guarantee that the company will be successful.
#
# `Angel investors, venture capitalists, and crowdfunding platforms` can all be good sources of seed funding for startups. Each has its own advantages and disadvantages, so it is important to choose the right one for your company.
#
#
# Columns :
#
# - `seed` - first official funding stage
#
# - `venture` - capital invested in a project in which there is a substantial element of risk, typically a new or expanding business.
#
# - `equity_crowdfunding` - involves exchanging relatively small amounts of cash allowing investors to own a proportionate slice of equity in the business.
#
# - `undisclosed` - investment amount not shared publicitly
#
# - `convertible_note` - a technique that seed investors use to invest in early-stage businesses whose valuation is not yet determined. It is a short-term debt structured to a start-up investment that isn't ready to get evaluated yet. Once the company is valued, Convertible Note is changed into equity.
#
#     Convertible note atau obligasi konversi adalah surat utang yang diterbitkan startup untuk dibeli investor. Pada saat jatuh tempo, investor memiliki opsi untuk mengonversi piutang menjadi ekuitas, di mana ekuitas tersebut diberikan dalam bentuk saham, baik saham biasa ataupun saham preferen.
#
#     Pembiayaan ekuitas (equity financing). Berdasarkan ada Investopedia, pembiayaan ekuitas atau yang dikenal juga dengan equity financing ini merupakan penanaman modal lewat penjualan saham di perusahaan. Pembiayaan ekuitas (equity financing) berbeda dengan pembiayaan utang. Ini disebabkan karena perusahaan yang menerima modal tidak memiliki kewajiban untuk membayar bunga serta pokok dari utang tersebut.
#
# - `debt_financing` - is a type of funding provided to startups by an investor or lender, such as a bank, for a certain amount of time.
#
# - `angel` - angel investors are wealthy private investors focused on financing small business ventures in exchange for equity. angel investor provides initial seed money for startup businesses, usually in exchange for ownership equity in the company.
#
# - `grant` - A business grant is a sum of money given to a business in order to help them further their business. They're usually distributed by governments, corporations, foundations, or trusts.
#
# - `private_equity` - is an alternative investment class that invests in or acquires private companies that are not listed on a public stock exchange
#
# - IPO – An (Initial Public Offering) or stock launch is a public offering in which shares of a company are sold to institutional investors
#
# IPO adalah singkatan dari Initial Public Offering atau jika diartikan dalam Bahasa Indonesia, IPO adalah Penawaran Umum Perdana Saham.
#
# Dikutip dari Investopedia, IPO adalah proses penawaran saham perusahaan swasta kepada publik di mana ada penerbitan saham baru untuk pertama kalinya yang dijual untuk publik secara luas.
#
# IPO saham memungkinkan perusahaan untuk meningkatkan modal ekuitas dari investor publik. IPO adalah semacam transisi dari perusahaan swasta ke perusahaan publik, dari awalnya perusahaan yang sepenuhnya dimiliki terbatas secara privat kemudian menjadi perusahaan terbuka yang bisa dimiliki siapa saja.
#
# IPO saham adalah sekaligus menjadi penanda di mana sebuah perusahaan swasta (PT tertutup) menjadi perusahaan publik (Tbk). Oleh karenanya, IPO saham ini juga sering disebut dengan go public
#
#     - `post_ipo_equity` - a post IPO equity round takes place when firms invest in a company after the company has already gone public.
#     - `post_ipo_debt` -  - a post IPO debt round is a transaction when corporates loan a company money after the company has already gone public.
#
# - `secondary_market` - A secondary market is any financial market where investors buy and sell securities (such as stocks or bonds) that have already been issued by a company.1 It’s “secondary” to a primary market, where securities are issued and sold directly by the company. In other words, when an initial purchaser of a stock from a company sells that security to another investor, the security transaction moves into a secondary market. The main difference between a primary investment offering and a secondary investment offering is how the shares (stocks) are acquired. In a primary investment offering, investors are purchasing shares (stocks) directly from the issuer. However, in a secondary investment offering, investors are purchasing shares (stocks) from sources other than the issuer (employees, former employees, or investors).
#
# - `product_crowdfunding` - crowdfunding is a way of raising money to finance projects
#
#     `Rewards-based crowdfunding` involves offering backers rewards, such as products, services, or experiences, in exchange for their financial contributions. This type of crowdfunding is often used to fund creative projects, such as films, video games, or new products.
#
#     `Equity crowdfunding` involves selling shares of ownership in a company to investors in exchange for their financial contributions. This type of crowdfunding is often used to fund startups or small businesses.
#
# - `round_A` - `round_H` - different rounds of funding
#
# In the context of startup funding, the terms "Round A" to "Round H" refer to different stages of financing that a startup may go through as it grows and seeks additional capital to expand its operations. These rounds are often referred to as "funding rounds."
#
# Here's a summary of what each round typically represents:
#
# - Round A: Also known as Series A, this is the first significant round of financing after the seed stage. Startups in this round have a proven business model and some degree of market traction. The funding is usually used to fuel growth, expand operations, and further develop the product or service.
#
# - Round B: Series B funding comes after Series A and is typically raised when the startup shows continued growth and progress. In this round, the company is expected to scale up its operations and may enter new markets.
#
# - Round C: Series C funding is raised to accelerate growth, expand into new markets, or develop new product lines. Startups at this stage usually have a well-established customer base and strong revenue growth.
#
# - Round D and beyond: As the startup continues to grow, subsequent funding rounds are named Series D, E, F, and so on, based on the alphabet. These rounds are typically aimed at further scaling the company, acquiring other businesses, or preparing for an IPO (Initial Public Offering).
#
# Each funding round involves attracting investments from venture capitalists, angel investors, and sometimes institutional investors, with the goal of providing the startup with the necessary financial resources to achieve its growth objectives. The terms and conditions of each funding round can vary depending on the company's performance, market conditions, and investor appetite.
#
#
#
# - https://data.crunchbase.com/docs
# - https://data.crunchbase.com/docs/daily-csv-export
# - https://data.crunchbase.com/v3.1/docs/organization
# - https://data.crunchbase.com/v3.1/docs/funding-types
# - https://libera.id/blogs/convertible-note/#:~:text=Convertible%20note%20atau%20obligasi%20konversi,saham%20biasa%20ataupun%20saham%20preferen.
# - https://money.kompas.com/read/2023/02/16/130419226/apa-itu-ipo-saham-arti-mekanisme-dan-tips-membelinya?page=all#:~:text=IPO%20saham%20adalah%20salah%20satu,adalah%20Penawaran%20Umum%20Perdana%20Saham.
# - https://www.most.co.id/tips-investasi/mengenal-initial-public-offering
# - https://www.mncsekuritas.id/pages/investor-wajib-tahu-3-istilah-penting-tentang-ipo#:~:text=IPO%20sendiri%20merupakan%20kondisi%20ketika,IPO%20yang%20harus%20Anda%20ketahui.
